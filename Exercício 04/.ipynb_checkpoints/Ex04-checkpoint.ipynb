# %%
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense 
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Importando os dados

# %% [markdown]
# Base de dados com informações para classificar câncer de mama em benígno ou malígno. A base é dividida em dois arquivos: um com os atributos previsores e outro com as classes 0 ou 1 (benígno ou malígno).

# %%
previsores = pd.read_csv('entradas_breast.csv')
previsores.head(5)
# Out:
#     radius_mean   texture_mean   perimeter_mean   area_mean   smoothness_mean  \
# 0         17.99          10.38           122.80      1001.0           0.11840
# 1         20.57          17.77           132.90      1326.0           0.08474
# 2         19.69          21.25           130.00      1203.0           0.10960
# 3         11.42          20.38            77.58       386.1           0.14250
# 4         20.29          14.34           135.10      1297.0           0.10030
#
#     compactness_mean   concavity_mean  concave_points_mean   symmetry_mean  \
# 0            0.27760           0.3001              0.14710          0.2419
# 1            0.07864           0.0869              0.07017          0.1812
# 2            0.15990           0.1974              0.12790          0.2069
# 3            0.28390           0.2414              0.10520          0.2597
# 4            0.13280         198.0000              0.10430          0.1809
#
# ...

# %%
classe = pd.read_csv('saidas_breast.csv')
classe.head(5)
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %% [markdown]
# Separando os dados de teste e treinamento, onde 25% da base foi separada para teste.

# %%
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.25)

# %% [markdown]
# # Criando a Rede Neural

# %% [markdown]
# Criação e treinamento da rede.

# %%
classificador = Sequential()
classificador.add(Dense(units = 16, activation= 'relu', kernel_initializer = 'random_uniform', input_dim = 30))
classificador.add(Dense(units = 16, activation= 'relu', kernel_initializer = 'random_uniform'))
classificador.add(Dense(units = 16, activation= 'relu', kernel_initializer = 'random_uniform'))
classificador.add(Dense(units = 1, activation = 'sigmoid'))
otimizador = keras.optimizers.Adam(lr = 0.01, decay = 0.001, clipvalue = 0.5)
classificador.compile(optimizer = otimizador, loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
classificador.fit(previsores_treinamento, classe_treinamento, batch_size = 10, epochs = 200)
# Out:
# Epoch 1/200
# 426/426 [==============================] - 0s 318us/step - loss: 0.5833 - binary_accuracy: 0.6150
# Epoch 2/200
# 426/426 [==============================] - 0s 63us/step - loss: 0.6252 - binary_accuracy: 0.6596
# Epoch 3/200
# 426/426 [==============================] - 0s 63us/step - loss: 0.5832 - binary_accuracy: 0.7042
# Epoch 4/200
# 426/426 [==============================] - 0s 66us/step - loss: 0.4658 - binary_accuracy: 0.7700
# Epoch 5/200
# 426/426 [==============================] - 0s 68us/step - loss: 0.4143 - binary_accuracy: 0.8216
# Epoch 6/200
# 426/426 [==============================] - 0s 63us/step - loss: 0.4240 - binary_accuracy: 0.8286
# Epoch 7/200
# 426/426 [==============================] - 0s 64us/step - loss: 0.3364 - binary_accuracy: 0.8873
# Epoch 8/200
# 426/426 [==============================] - 0s 63us/step - loss: 0.2932 - binary_accuracy: 0.8779
# Epoch 9/200
# ...

# %% [markdown]
# # Realizando Previsões

# %% [markdown]
# Prevendo com a base de teste e transformando os resultados de porcentagem para 0 ou 1

# %%
previsoes = classificador.predict(previsores_teste)
previsoes = (previsoes > 0.5)

# %% [markdown]
# # Resultados

# %% [markdown]
# Matriz de confusão e acurácia

# %%
precisao = accuracy_score(classe_teste, previsoes)
matriz = confusion_matrix(classe_teste, previsoes)
resultado = classificador.evaluate(previsores_teste, classe_teste)
print("\nMatriz de confusão: ")
print(matriz)
print("\nPrecisão: ", precisao)
# Out:
# 143/143 [==============================] - 0s 125us/step
#
# Matriz de confusão:
# [[41 13]
#  [10 79]]
#
# Precisão:  0.8391608391608392
